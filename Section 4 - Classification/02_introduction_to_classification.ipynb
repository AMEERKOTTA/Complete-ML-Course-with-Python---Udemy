# %% [markdown]
# ### INTRODUCTION TO CLASSIFICATION
#
# *SUPERVISED LEARNING :-- Which means the data comes with an addictional attributes that we want to predict.*
#
# **CLASSIFICATION**
#
# + Samples belongs to two or more classes.
# + We want to learn from already labelled data.
# + We want to learn how tro predict the class if we get an Unlabelled data.
#
#
# **REGRESSION**
#
# +
